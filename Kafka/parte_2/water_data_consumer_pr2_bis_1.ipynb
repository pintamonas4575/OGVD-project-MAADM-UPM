# %%
from kafka import KafkaConsumer
import json
import matplotlib.pyplot as plt
import time

# %%
# Initialize data storage for plotting
timestamps = []
water_temperatures = []
ph_levels = []
turbidities = []
dissolved_oxygen_levels = []

# %%
# Kafka configuration
def initialize_consumer():
    kafka_topic = "water_quality"
    kafka_bootstrap_servers = ["localhost:9092"]

    # Create Kafka consumer
    consumer = KafkaConsumer(
        kafka_topic,
        bootstrap_servers=kafka_bootstrap_servers,
        value_deserializer=lambda m: json.loads(m.decode('utf-8')),
        auto_offset_reset='latest',
        enable_auto_commit=True,
        group_id = "water_quality_consumers"
    )
    return consumer

# %%
# Receive all published messages and update plot
def update_plot(consumer):
    try:
        for message in consumer:
            # Parse the message
            sensor_data = message.value
            sensor_key = message.key
            print(f"Received: {sensor_data} from sensor {sensor_key}")

            # Update data storage
            timestamps.append(sensor_data['timestamp'])
            water_temperatures.append(sensor_data['water_temperature'])
            ph_levels.append(sensor_data['ph_level'])
            turbidities.append(sensor_data['turbidity'])
            dissolved_oxygen_levels.append(sensor_data['dissolved_oxygen'])

            # Keep only the last 100 entries for plotting
            if len(timestamps) > 100:
                timestamps.pop(0)
                water_temperatures.pop(0)
                ph_levels.pop(0)
                turbidities.pop(0)
                dissolved_oxygen_levels.pop(0)

            # Clear the current axes and redraw the plots
            plt.figure(figsize=(10, 8))

            plt.subplot(2, 2, 1)
            plt.plot(timestamps, water_temperatures, label="Water Temperature", color="blue")
            plt.title("Water Temperature")
            plt.ylabel("°C")

            plt.subplot(2, 2, 2)
            plt.plot(timestamps, ph_levels, label="pH Level", color="green")
            plt.title("pH Level")
            plt.ylabel("pH")

            plt.subplot(2, 2, 3)
            plt.plot(timestamps, turbidities, label="Turbidity", color="orange")
            plt.title("Turbidity")
            plt.ylabel("NTU")

            plt.subplot(2, 2, 4)
            plt.plot(timestamps, dissolved_oxygen_levels, label="Dissolved Oxygen", color="red")
            plt.title("Dissolved Oxygen")
            plt.ylabel("mg/L")

            plt.tight_layout()

            # Save the plot as an image
            plt.savefig(f"water_quality_plot_{sensor_key}.png")
            plt.close()

            break  # Process one message at a time
    except KeyboardInterrupt:
        print("Stopped consuming messages.")
        consumer.close()

# %%
consumer = initialize_consumer()
print(f"Created consumer subscribed to Kafka topic 'water_quality'.")

try:
    while True:
        update_plot(consumer)
except KeyboardInterrupt:
    print("Stopped visualization.")
    consumer.close()
# Out:
# Created consumer subscribed to Kafka topic 'water_quality'.
# Received: {'timestamp': 1741188556, 'water_temperature': 27.83257595060122, 'ph_level': 8.271102341048163, 'turbidity': 21.93, 'dissolved_oxygen': 7.2} from sensor b'0'
# Received: {'timestamp': 1741188558, 'water_temperature': 27.672128754612082, 'ph_level': 7.806698882880508, 'turbidity': 9.45, 'dissolved_oxygen': 5.93} from sensor b'0'
# Received: {'timestamp': 1741188560, 'water_temperature': 27.837857033639985, 'ph_level': 7.949647331228021, 'turbidity': 39.42, 'dissolved_oxygen': 9.14} from sensor b'0'
# Received: {'timestamp': 1741188562, 'water_temperature': 27.30133228291835, 'ph_level': 8.328716657081499, 'turbidity': 16.02, 'dissolved_oxygen': 8.74} from sensor b'0'
# Received: {'timestamp': 1741188564, 'water_temperature': 26.988738447093812, 'ph_level': 8.421916704050595, 'turbidity': 25.48, 'dissolved_oxygen': 6.07} from sensor b'0'
# Received: {'timestamp': 1741188566, 'water_temperature': 28.674263823044118, 'ph_level': 8.287524030602194, 'turbidity': 26.31, 'dissolved_oxygen': 11.83} from sensor b'0'
# Received: {'timestamp': 1741188568, 'water_temperature': 28.80249220484987, 'ph_level': 8.384734062672814, 'turbidity': 45.6, 'dissolved_oxygen': 6.91} from sensor b'0'
# Received: {'timestamp': 1741188570, 'water_temperature': 27.635244459845943, 'ph_level': 7.641546377217969, 'turbidity': 43.16, 'dissolved_oxygen': 10.6} from sensor b'0'
# Received: {'timestamp': 1741188572, 'water_temperature': 28.39727223226104, 'ph_level': 7.647099563075311, 'turbidity': 35.17, 'dissolved_oxygen': 10.8} from sensor b'0'
# Received: {'timestamp': 1741188574, 'water_temperature': 27.85189397223068, 'ph_level': 7.761817754735409, 'turbidity': 41.58, 'dissolved_oxygen': 5.48} from sensor b'0'
# Received: {'timestamp': 1741188576, 'water_temperature': 27.297698157765126, 'ph_level': 8.216885636047026, 'turbidity': 38.41, 'dissolved_oxygen': 11.01} from sensor b'0'
# Received: {'timestamp': 1741188578, 'water_temperature': 27.071266671994586, 'ph_level': 7.652608176175097, 'turbidity': 23.47, 'dissolved_oxygen': 9.52} from sensor b'0'
# Received: {'timestamp': 1741188580, 'water_temperature': 28.777018531001485, 'ph_level': 7.643033078329196, 'turbidity': 19.29, 'dissolved_oxygen': 5.93} from sensor b'0'
# Received: {'timestamp': 1741188582, 'water_temperature': 27.52774340325318, 'ph_level': 7.697153538066127, 'turbidity': 31.0, 'dissolved_oxygen': 8.35} from sensor b'0'
# Received: {'timestamp': 1741188584, 'water_temperature': 27.251818774757794, 'ph_level': 8.052932190953163, 'turbidity': 38.53, 'dissolved_oxygen': 10.39} from sensor b'0'
# Received: {'timestamp': 1741188586, 'water_temperature': 27.61020543771064, 'ph_level': 8.055579249591826, 'turbidity': 46.54, 'dissolved_oxygen': 11.16} from sensor b'0'
# Received: {'timestamp': 1741188588, 'water_temperature': 27.504784554832234, 'ph_level': 8.40777317002116, 'turbidity': 23.43, 'dissolved_oxygen': 11.49} from sensor b'0'
# Received: {'timestamp': 1741188590, 'water_temperature': 27.653740833175938, 'ph_level': 7.586567920851183, 'turbidity': 21.48, 'dissolved_oxygen': 5.54} from sensor b'0'
# Received: {'timestamp': 1741188592, 'water_temperature': 28.781080165991142, 'ph_level': 7.677644380634186, 'turbidity': 23.35, 'dissolved_oxygen': 9.23} from sensor b'0'
# Received: {'timestamp': 1741188594, 'water_temperature': 28.651067995715604, 'ph_level': 7.7672593130263134, 'turbidity': 28.42, 'dissolved_oxygen': 5.58} from sensor b'0'
# Received: {'timestamp': 1741188596, 'water_temperature': 28.895856422109404, 'ph_level': 7.639991583769421, 'turbidity': 28.36, 'dissolved_oxygen': 6.91} from sensor b'0'
# Received: {'timestamp': 1741188598, 'water_temperature': 27.927255589296706, 'ph_level': 8.488191754994533, 'turbidity': 22.91, 'dissolved_oxygen': 9.49} from sensor b'0'
# Received: {'timestamp': 1741188600, 'water_temperature': 27.27926074498278, 'ph_level': 8.497293842562218, 'turbidity': 25.62, 'dissolved_oxygen': 9.0} from sensor b'0'
# Received: {'timestamp': 1741188602, 'water_temperature': 28.12757646372691, 'ph_level': 8.130102943045856, 'turbidity': 27.44, 'dissolved_oxygen': 11.39} from sensor b'0'
# Received: {'timestamp': 1741188481, 'water_temperature': 28.065761150769692, 'ph_level': 8.541734627073344, 'turbidity': 47.3, 'dissolved_oxygen': 9.67} from sensor b'1'
# Received: {'timestamp': 1741188483, 'water_temperature': 27.29010606878353, 'ph_level': 7.885698090022659, 'turbidity': 5.67, 'dissolved_oxygen': 9.04} from sensor b'1'
# Received: {'timestamp': 1741188485, 'water_temperature': 28.70435418075722, 'ph_level': 7.650748171430488, 'turbidity': 33.54, 'dissolved_oxygen': 6.58} from sensor b'1'
# Received: {'timestamp': 1741188487, 'water_temperature': 28.492087913596734, 'ph_level': 8.569879562096238, 'turbidity': 45.82, 'dissolved_oxygen': 9.92} from sensor b'1'
# Received: {'timestamp': 1741188489, 'water_temperature': 27.91088634878604, 'ph_level': 8.338957785357502, 'turbidity': 37.28, 'dissolved_oxygen': 5.96} from sensor b'1'
# Received: {'timestamp': 1741188491, 'water_temperature': 26.979619353458585, 'ph_level': 7.815652968526416, 'turbidity': 25.54, 'dissolved_oxygen': 8.43} from sensor b'1'
# Received: {'timestamp': 1741188493, 'water_temperature': 28.49921561686937, 'ph_level': 7.755019194621111, 'turbidity': 24.4, 'dissolved_oxygen': 11.91} from sensor b'1'
# Received: {'timestamp': 1741188495, 'water_temperature': 27.87045022748703, 'ph_level': 7.608527731537549, 'turbidity': 18.81, 'dissolved_oxygen': 9.32} from sensor b'1'
# Received: {'timestamp': 1741188497, 'water_temperature': 27.061934342144603, 'ph_level': 7.588377684841074, 'turbidity': 39.16, 'dissolved_oxygen': 6.33} from sensor b'1'
# Received: {'timestamp': 1741188499, 'water_temperature': 28.628959795717037, 'ph_level': 7.7451267949315366, 'turbidity': 29.7, 'dissolved_oxygen': 10.93} from sensor b'1'
# Received: {'timestamp': 1741188501, 'water_temperature': 28.924218005831264, 'ph_level': 8.350420793608551, 'turbidity': 9.39, 'dissolved_oxygen': 7.74} from sensor b'1'
# Received: {'timestamp': 1741188503, 'water_temperature': 27.77784257163422, 'ph_level': 7.676518567419171, 'turbidity': 36.62, 'dissolved_oxygen': 10.97} from sensor b'1'
# Received: {'timestamp': 1741188505, 'water_temperature': 27.98405684468173, 'ph_level': 8.250674448936193, 'turbidity': 19.41, 'dissolved_oxygen': 9.19} from sensor b'1'
# Received: {'timestamp': 1741188507, 'water_temperature': 27.15481038457269, 'ph_level': 8.065343568648293, 'turbidity': 43.42, 'dissolved_oxygen': 8.08} from sensor b'1'
# Received: {'timestamp': 1741188509, 'water_temperature': 28.75536351611178, 'ph_level': 8.385989114558285, 'turbidity': 11.68, 'dissolved_oxygen': 9.96} from sensor b'1'
# Received: {'timestamp': 1741188511, 'water_temperature': 28.246210529523793, 'ph_level': 8.067100079503422, 'turbidity': 33.93, 'dissolved_oxygen': 8.63} from sensor b'1'
# Received: {'timestamp': 1741188513, 'water_temperature': 28.018381794448345, 'ph_level': 7.916758649707284, 'turbidity': 11.5, 'dissolved_oxygen': 8.91} from sensor b'1'
# Received: {'timestamp': 1741188515, 'water_temperature': 27.492707760304867, 'ph_level': 8.169868994864851, 'turbidity': 6.94, 'dissolved_oxygen': 11.32} from sensor b'1'
# Received: {'timestamp': 1741188517, 'water_temperature': 27.78802513000743, 'ph_level': 7.652030042556431, 'turbidity': 14.49, 'dissolved_oxygen': 11.31} from sensor b'1'
# Received: {'timestamp': 1741188519, 'water_temperature': 28.634456265538027, 'ph_level': 8.00962801032405, 'turbidity': 10.57, 'dissolved_oxygen': 6.71} from sensor b'1'
# Received: {'timestamp': 1741188521, 'water_temperature': 28.555202034214695, 'ph_level': 7.65596299181186, 'turbidity': 45.03, 'dissolved_oxygen': 7.75} from sensor b'1'
# Received: {'timestamp': 1741188523, 'water_temperature': 27.265503917610786, 'ph_level': 7.722955152149117, 'turbidity': 28.87, 'dissolved_oxygen': 9.93} from sensor b'1'
# Received: {'timestamp': 1741188525, 'water_temperature': 27.05021913789925, 'ph_level': 8.528303606186908, 'turbidity': 8.99, 'dissolved_oxygen': 9.84} from sensor b'1'
# Received: {'timestamp': 1741188527, 'water_temperature': 28.887525785062415, 'ph_level': 7.865244038831456, 'turbidity': 33.27, 'dissolved_oxygen': 10.72} from sensor b'1'
# Received: {'timestamp': 1741188529, 'water_temperature': 27.29108716294744, 'ph_level': 7.944899774403543, 'turbidity': 47.58, 'dissolved_oxygen': 9.83} from sensor b'1'
# Received: {'timestamp': 1741188531, 'water_temperature': 27.21852947520636, 'ph_level': 7.749362420372834, 'turbidity': 39.59, 'dissolved_oxygen': 5.68} from sensor b'1'
# Received: {'timestamp': 1741188533, 'water_temperature': 28.548538310514793, 'ph_level': 8.27784905014273, 'turbidity': 28.01, 'dissolved_oxygen': 5.3} from sensor b'1'
# Received: {'timestamp': 1741188535, 'water_temperature': 28.69321266900088, 'ph_level': 8.493634643402187, 'turbidity': 23.85, 'dissolved_oxygen': 5.74} from sensor b'1'
# Received: {'timestamp': 1741188537, 'water_temperature': 28.185266101110017, 'ph_level': 7.830588283392763, 'turbidity': 44.02, 'dissolved_oxygen': 8.57} from sensor b'1'
# Received: {'timestamp': 1741188539, 'water_temperature': 27.916084004465134, 'ph_level': 8.388262876496931, 'turbidity': 45.84, 'dissolved_oxygen': 10.62} from sensor b'1'
# Received: {'timestamp': 1741188541, 'water_temperature': 27.559368822792027, 'ph_level': 7.66309536163641, 'turbidity': 11.34, 'dissolved_oxygen': 9.36} from sensor b'1'
# Received: {'timestamp': 1741188543, 'water_temperature': 28.539633421695683, 'ph_level': 8.20650182303254, 'turbidity': 17.04, 'dissolved_oxygen': 6.98} from sensor b'1'
# Received: {'timestamp': 1741188545, 'water_temperature': 28.437086625214885, 'ph_level': 8.127780620791894, 'turbidity': 7.65, 'dissolved_oxygen': 10.99} from sensor b'1'
